# %% [markdown]
# <a href="https://colab.research.google.com/github/ranatushar7579/Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Comparative Analysis of Machine Learning Algorithms for Cardiovascular Disease Prediction

# %% [markdown]
#  ## IMPORT LIBRARIES

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
    roc_curve
)

# %% [markdown]
#  ## DATASET COLLECTION

# %% [markdown]
# > DATASET LOADING

# %%
# READ CSV FILE
df = pd.read_csv("cardio_train_with_age_years.csv", sep=";")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
import pandas as pd

# Load original CSV
df = pd.read_csv("cardio_train_with_age_years.csv", sep=";")

# Convert age from days to years
df["age_years"] = (df["age"] / 365.25).round().astype(int)

# Save updated CSV
df.to_csv("cardio_train_with_age_years.csv", sep=";", index=False)

print("age_years column successfully added!")
print(df[["age", "age_years"]].head())
# Out:
# age_years column successfully added!
#      age  age_years
# 0  18393         50
# 1  20228         55
# 2  18857         52
# 3  17623         48
# 4  17474         48

# %%
# OVERVIEW OF DATASET

print("=" * 60)
print("DATASET OVERVIEW")
print("=" * 60)

print(f"Number of rows    : {df.shape[0]:,}")
print(f"Number of columns : {df.shape[1]}")

print("\nColumn names:")
print(df.columns.tolist())

print("\nFirst 5 records:")
display(df.head())

print("\nLast 5 records:")
display(df.tail())
# Out:
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Number of rows    : 70,000
# Number of columns : 14
#
# Column names:
# ['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years']
#
# First 5 records:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years
# 0     0       1       0         50
# 1     0       1       1         55
# 2     0       0       1         52
# 3     0       1       1         48
# 4     0       0       0         48
# Last 5 records:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  age_years
# 69995      1     0       1       0         53
# 69996      0     0       1       1         62
# 69997      0     1       0       1         52
# 69998      0     0       0       1         61
# 69999      0     0       1       0         56

# %% [markdown]
#  ## STATISTICAL SUMMARY

# %% [markdown]
# > Basic Data Analysis

# %%
# DATASET SIZE

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 70000
# Number of columns: 14

# %% [markdown]
# > Check Datatypes

# %%
print(df.dtypes)
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# age_years        int64
# dtype: object

# %% [markdown]
# > Complete Dataset Information

# %%
print("DATASET INFORMATION")
df.info()
# Out:
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
#  13  age_years    70000 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 7.5 MB

# %%
# BASIC DATA ANALYSIS(TABLULAR FORM)

print(df.describe())
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# std      154.011419    188.472530      0.680250      0.572270      0.283484
# min     -150.000000    -70.000000      1.000000      1.000000      0.000000
# 25%      120.000000     80.000000      1.000000      1.000000      0.000000
# 50%      120.000000     80.000000      1.000000      1.000000      0.000000
# 75%      140.000000     90.000000      2.000000      1.000000      0.000000
# max    16020.000000  11000.000000      3.000000      3.000000      1.000000
#
#                alco        active        cardio     age_years
# count  70000.000000  70000.000000  70000.000000  70000.000000
# mean       0.053771      0.803729      0.499700     53.303157
# std        0.225568      0.397179      0.500003      6.760171
# min        0.000000      0.000000      0.000000     30.000000
# 25%        0.000000      1.000000      0.000000     48.000000
# 50%        0.000000      1.000000      0.000000     54.000000
# 75%        0.000000      1.000000      1.000000     58.000000
# max        1.000000      1.000000      1.000000     65.000000

# %%
# TRANPOSE OF DESCRIBE
print("DESCRIPTIVE STATISTICS")
df.describe().T
# Out:
# DESCRIPTIVE STATISTICS
#                count          mean           std      min       25%      50%  \
# id           70000.0  49972.419900  28851.302323      0.0  25006.75  50001.5
# age          70000.0  19468.865814   2467.251667  10798.0  17664.00  19703.0
# gender       70000.0      1.349571      0.476838      1.0      1.00      1.0
# height       70000.0    164.359229      8.210126     55.0    159.00    165.0
# weight       70000.0     74.205690     14.395757     10.0     65.00     72.0
# ap_hi        70000.0    128.817286    154.011419   -150.0    120.00    120.0
# ap_lo        70000.0     96.630414    188.472530    -70.0     80.00     80.0
# cholesterol  70000.0      1.366871      0.680250      1.0      1.00      1.0
# gluc         70000.0      1.226457      0.572270      1.0      1.00      1.0
# smoke        70000.0      0.088129      0.283484      0.0      0.00      0.0
# alco         70000.0      0.053771      0.225568      0.0      0.00      0.0
# active       70000.0      0.803729      0.397179      0.0      1.00      1.0
# cardio       70000.0      0.499700      0.500003      0.0      0.00      0.0
# age_years    70000.0     53.303157      6.760171     30.0     48.00     54.0
#
#                   75%      max
# id           74889.25  99999.0
# age          21327.00  23713.0
# gender           2.00      2.0
# height         170.00    250.0
# weight          82.00    200.0
# ap_hi          140.00  16020.0
# ap_lo           90.00  11000.0
# cholesterol      2.00      3.0
# gluc             1.00      3.0
# smoke            0.00      1.0
# alco             0.00      1.0
# active           1.00      1.0
# cardio           1.00      1.0
# age_years       58.00     65.0

# %%
# CHECK UNIQUE VALUES

print("UNIQUE VALUES")

print("Gender values:")
print(df["gender"].unique())

print("\nCholesterol values:")
print(df["cholesterol"].unique())

print("\nGlucose values:")
print(df["gluc"].unique())

print("\nTarget values:")
print(df["cardio"].unique())
# Out:
# UNIQUE VALUES
# Gender values:
# [2 1]
#
# Cholesterol values:
# [1 3 2]
#
# Glucose values:
# [1 2 3]
#
# Target values:
# [0 1]

# %%
# TARGET VALUES DISTRIBUTION
# VALUE COUNTS

print("UNIQUE VALUES")

print("\nCVD Value Counts:")
print(df["cardio"].value_counts())

# Gender distribution
print("\nGender Value Counts:")
print(df["gender"].value_counts())

# Cholesterol distribution
print("\nCholesterol Value Counts:")
print(df["cholesterol"].value_counts())

# Glucose distribution
print("\nGlucose Value Counts:")
print(df["gluc"].value_counts())

# Smoking distribution
print("\nSmoking Value Counts:")
print(df["smoke"].value_counts())

# Alcohol distribution
print("\nAlcohol Value Counts:")
print(df["alco"].value_counts())

# Physical Activity distribution
print("\nPhysical Activity Value Counts:")
print(df["active"].value_counts())
# Out:
# UNIQUE VALUES
#
# CVD Value Counts:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64
#
# Gender Value Counts:
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64
#
# Cholesterol Value Counts:
# cholesterol
# 1    52385
# 2     9549
# 3     8066
# Name: count, dtype: int64
#
# Glucose Value Counts:
# gluc
# 1    59479
# 3     5331
# 2     5190
# Name: count, dtype: int64
#
# Smoking Value Counts:
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64
#
# Alcohol Value Counts:
# alco
# 0    66236
# 1     3764
# Name: count, dtype: int64
#
# Physical Activity Value Counts:
# active
# 1    56261
# 0    13739
# Name: count, dtype: int64

# %% [markdown]
# ## DATA INSPECTION

# %% [markdown]
# > Check Missing Values

# %%
missing_summary = pd.DataFrame({
    "Missing_Count": df.isnull().sum(),
})
print(missing_summary)

# HEATMAP OF MISSING VALUES
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Value Heatmap")
plt.show()
# Out:
#              Missing_Count
# id                       0
# age                      0
# gender                   0
# height                   0
# weight                   0
# ap_hi                    0
# ap_lo                    0
# cholesterol              0
# gluc                     0
# smoke                    0
# alco                     0
# active                   0
# cardio                   0
# age_years                0

# %% [markdown]
# > Check Duplicate Records

# %%
print("Shape Before Removing Duplicates :", df.shape)

duplicates = df.duplicated().sum()

print("Duplicate Records :", duplicates)

df = df.drop_duplicates()

print("Shape After Removing Duplicates :", df.shape)
# Out:
# Shape Before Removing Duplicates : (70000, 14)
# Duplicate Records : 0
# Shape After Removing Duplicates : (70000, 14)

# %% [markdown]
# > Validate Age

# %%
# Convert age from days to years for inspection
age_years = df["age"] / 365.25

print(f"Minimum age: {age_years.min():.2f} years")
print(f"Maximum age: {age_years.max():.2f} years")
# Out:
# Minimum age: 29.56 years
# Maximum age: 64.92 years

# %% [markdown]
# > Validate Height

# %%
print("Height statistics:")
print(df["height"].describe())
# Out:
# Height statistics:
# count    70000.000000
# mean       164.359229
# std          8.210126
# min         55.000000
# 25%        159.000000
# 50%        165.000000
# 75%        170.000000
# max        250.000000
# Name: height, dtype: float64

# %% [markdown]
# > Validate Weight

# %%
print("\nWeight statistics:")
print(df["weight"].describe())
# Out:
# Weight statistics:
# count    70000.000000
# mean        74.205690
# std         14.395757
# min         10.000000
# 25%         65.000000
# 50%         72.000000
# 75%         82.000000
# max        200.000000
# Name: weight, dtype: float64

# %% [markdown]
# > Validate Blood Pressure

# %%
print("\nSystolic BP statistics:")
print(df["ap_hi"].describe())

print("\nDiastolic BP statistics:")
print(df["ap_lo"].describe())
# Out:
# Systolic BP statistics:
# count    70000.000000
# mean       128.817286
# std        154.011419
# min       -150.000000
# 25%        120.000000
# 50%        120.000000
# 75%        140.000000
# max      16020.000000
# Name: ap_hi, dtype: float64
#
# Diastolic BP statistics:
# count    70000.000000
# mean        96.630414
# std        188.472530
# min        -70.000000
# 25%         80.000000
# 50%         80.000000
# 75%         90.000000
# max      11000.000000
# Name: ap_lo, dtype: float64

# %% [markdown]
# > Detect Logically Impossible Blood Pressure

# %%
invalid_bp = df[df["ap_lo"] >= df["ap_hi"]]

print(f"Records where diastolic BP >= systolic BP: {len(invalid_bp):,}")

display(invalid_bp.head())
# Out:
# Records where diastolic BP >= systolic BP: 1,236
#       id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 228  314  17489       2     183    98.0    160   1100            1     2
# 241  334  21932       2     157    60.0    160   1000            2     1
# 260  357  18217       1     150    83.0    140    800            1     1
# 329  458  23407       1     176    63.0    160   1000            2     2
# 345  482  18704       1     154    81.0    140   1000            2     1
#
#      smoke  alco  active  cardio  age_years
# 228      1     0       1       1         48
# 241      0     0       0       1         60
# 260      0     0       1       1         50
# 329      0     0       0       1         64
# 345      0     0       1       1         51

# %% [markdown]
# > Check Categorical Variables

# %%
categorical_columns = [
    "gender",
    "cholesterol",
    "gluc",
    "smoke",
    "alco",
    "active",
    "cardio"
]

for column in categorical_columns:
    if column in df.columns:
        print(f"\n{column}:")
        print(df[column].value_counts(dropna=False).sort_index())
# Out:
# gender:
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64
#
# cholesterol:
# cholesterol
# 1    52385
# 2     9549
# 3     8066
# Name: count, dtype: int64
#
# gluc:
# gluc
# 1    59479
# 2     5190
# 3     5331
# Name: count, dtype: int64
#
# smoke:
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64
#
# alco:
# alco
# 0    66236
# 1     3764
# Name: count, dtype: int64
#
# active:
# active
# 0    13739
# 1    56261
# Name: count, dtype: int64
#
# cardio:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# ## DATA CLEANING & MISSING VALUE HANDLING

# %%
#Create a separate copy so the original dataset remains unchanged
df_clean = df.copy()

print(f"Original dataset shape: {df_clean.shape}")
# Out:
# Original dataset shape: (70000, 14)

# %% [markdown]
# > Check Missing Values — df.isnull()

# %%
# Check missing values
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# age_years      0
# dtype: int64

# %% [markdown]
# > Fill Missing Values — fillna()

# %%
# Fill missing numerical values with median

df["age"] = df["age"].fillna(df["age"].median())
df["height"] = df["height"].fillna(df["height"].median())
df["weight"] = df["weight"].fillna(df["weight"].median())
df["ap_hi"] = df["ap_hi"].fillna(df["ap_hi"].median())
df["ap_lo"] = df["ap_lo"].fillna(df["ap_lo"].median())

print("Missing values filled successfully!")
# Out:
# Missing values filled successfully!

# %%
# Fill categorical missing values with mode

df["gender"] = df["gender"].fillna(df["gender"].mode()[0])
df["cholesterol"] = df["cholesterol"].fillna(df["cholesterol"].mode()[0])
df["gluc"] = df["gluc"].fillna(df["gluc"].mode()[0])

# %% [markdown]
# > Using SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# Create imputer
imputer = SimpleImputer(strategy="median")

# Fill missing numerical values
df[["age", "height", "weight", "ap_hi", "ap_lo"]] = imputer.fit_transform(
    df[["age", "height", "weight", "ap_hi", "ap_lo"]]
)

print("Missing values handled using SimpleImputer!")
# Out:
# Missing values handled using SimpleImputer!

# %% [markdown]
# > Final Check

# %%
# Check missing values after cleaning

print("Missing Values After Cleaning:")
print(df.isnull().sum())
# Out:
# Missing Values After Cleaning:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# age_years      0
# dtype: int64

# %% [markdown]
# > Remove Exact Duplicates

# %%
before_duplicates = len(df_clean)

df_clean = df_clean.drop_duplicates().reset_index(drop=True)

after_duplicates = len(df_clean)

print(f"Rows before duplicate removal: {before_duplicates:,}")
print(f"Rows after duplicate removal : {after_duplicates:,}")
print(f"Duplicates removed            : {before_duplicates - after_duplicates:,}")
# Out:
# Rows before duplicate removal: 70,000
# Rows after duplicate removal : 70,000
# Duplicates removed            : 0

# %% [markdown]
# > Remove Clearly Invalid Blood Pressure Records

# %%
invalid_bp_mask = (
    (df_clean["ap_hi"] <= 0) |
    (df_clean["ap_lo"] <= 0) |
    (df_clean["ap_lo"] >= df_clean["ap_hi"])
)

print(f"Invalid BP records: {invalid_bp_mask.sum():,}")

df_clean = df_clean.loc[~invalid_bp_mask].copy()
# Out:
# Invalid BP records: 0

# %% [markdown]
# > Validate Target

# %%
valid_target_values = {0, 1}

invalid_target = ~df_clean["cardio"].isin(valid_target_values)

print(f"Invalid target records: {invalid_target.sum():,}")

df_clean = df_clean.loc[~invalid_target].copy()
# Out:
# Invalid target records: 0

# %% [markdown]
# ## DUPLICATE REMOVAL & OUTLIER DETECTION

# %%
# NUMERIC VARIABLES

numerical_features = [
    "age",
    "bmi",
    "ap_hi",
    "ap_lo",
    "height",
    "weight"
]

numerical_features = [
    column for column in numerical_features
    if column in df_clean.columns
]

# %% [markdown]
# > IQR Outlier Detection Function

# %%
import numpy as np

def detect_iqr_outliers(dataframe, column):
    """
    Detect outliers using the Interquartile Range (IQR) method.
    """

    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)

    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    mask = (
        (dataframe[column] < lower_bound) |
        (dataframe[column] > upper_bound)
    )

    return {
        "Q1": q1,
        "Q3": q3,
        "IQR": iqr,
        "Lower_Bound": lower_bound,
        "Upper_Bound": upper_bound,
        "Outlier_Count": mask.sum(),
        "Outlier_Percentage": mask.mean() * 100
    }

# %% [markdown]
# > Generate Outlier Report

# %%
outlier_results = []

for column in numerical_features:

    result = detect_iqr_outliers(
        df_clean,
        column
    )

    result["Feature"] = column

    outlier_results.append(result)

outlier_report = pd.DataFrame(outlier_results)

outlier_report = outlier_report[
    [
        "Feature",
        "Q1",
        "Q3",
        "IQR",
        "Lower_Bound",
        "Upper_Bound",
        "Outlier_Count",
        "Outlier_Percentage"
    ]
]

display(outlier_report.round(2))
# Out:
#   Feature       Q1       Q3     IQR  Lower_Bound  Upper_Bound  Outlier_Count  \
# 0     age  17657.0  21324.0  3667.0      12156.5      26824.5              4
# 1   ap_hi    120.0    140.0    20.0         90.0        170.0           1048
# 2   ap_lo     80.0     90.0    10.0         65.0        105.0           3548
# 3  height    159.0    170.0    11.0        142.5        186.5            506
# 4  weight     65.0     82.0    17.0         39.5        107.5           1746
#
#    Outlier_Percentage
# 0                0.01
# 1                1.52
# 2                5.16
# 3                0.74
# 4                2.54

# %%
#2.
def find_outliers(df, column):

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[column] < lower) |
        (df[column] > upper)
    ]

    print("\nColumn :", column)
    print("Lower Limit :", lower)
    print("Upper Limit :", upper)
    print("Outliers :", len(outliers))

    return outliers

# %%
find_outliers(df, "weight")
# Out:
# Column : weight
# Lower Limit : 39.5
# Upper Limit : 107.5
# Outliers : 1819
#           id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 15        24  16782.0       2   172.0   112.0  120.0   80.0            1
# 62        81  20330.0       2   187.0   115.0  130.0   90.0            1
# 83       114  19570.0       1   152.0   110.0  160.0   90.0            1
# 196      267  22675.0       1   176.0   108.0  140.0   90.0            1
# 267      366  17460.0       1   165.0   115.0  150.0  100.0            1
# ...      ...      ...     ...     ...     ...    ...    ...          ...
# 69873  99799  19736.0       2   188.0   108.0  130.0   80.0            2
# 69946  99925  21333.0       1   164.0   115.0  130.0   80.0            1
# 69947  99930  23305.0       2   172.0   113.0  110.0   80.0            1
# 69981  99972  17500.0       2   182.0   110.0  130.0   90.0            2
# 69996  99995  22601.0       1   158.0   126.0  140.0   90.0            2
#
#        gluc  smoke  alco  active  cardio  age_years
# 15        1      0     0       0       1         46
# 62        1      0     1       1       0         56
# 83        1      0     0       1       1         54
# 196       1      0     0       0       0         62
# 267       1      0     0       1       1         48
# ...     ...    ...   ...     ...     ...        ...
# 69873     2      0     1       0       1         54
# 69946     1      0     0       1       1         58
# 69947     1      0     0       0       1         64
# 69981     2      0     0       1       1         48
# 69996     2      0     0       1       1         62
#
# [1819 rows x 14 columns]

# %%
find_outliers(df, "height")
# Out:
# Column : height
# Lower Limit : 142.5
# Upper Limit : 186.5
# Outliers : 519
#           id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 62        81  20330.0       2   187.0   115.0  130.0   90.0            1
# 76       105  20397.0       2   188.0   105.0  120.0   80.0            1
# 224      309  21800.0       2    76.0    55.0  120.0   80.0            1
# 249      343  18220.0       1   142.0    61.0  120.0   80.0            1
# 781     1086  23301.0       1   141.0    60.0  120.0   80.0            1
# ...      ...      ...     ...     ...     ...    ...    ...          ...
# 69430  99172  19040.0       1   140.0    52.0  150.0   80.0            2
# 69475  99226  19261.0       2   187.0    73.0  120.0   80.0            1
# 69589  99401  18286.0       2   192.0    83.0  110.0   70.0            1
# 69784  99673  17541.0       1   141.0    44.0  100.0   70.0            1
# 69873  99799  19736.0       2   188.0   108.0  130.0   80.0            2
#
#        gluc  smoke  alco  active  cardio  age_years
# 62        1      0     1       1       0         56
# 76        1      0     0       1       1         56
# 224       1      0     0       1       0         60
# 249       1      0     0       1       0         50
# 781       1      0     0       1       1         64
# ...     ...    ...   ...     ...     ...        ...
# 69430     1      0     0       1       1         52
# 69475     3      0     0       1       0         53
# 69589     1      0     1       0       0         50
# 69784     1      0     0       1       0         48
# 69873     2      0     1       0       1         54
#
# [519 rows x 14 columns]

# %%
find_outliers(df, "ap_hi")
# Out:
# Column : ap_hi
# Lower Limit : 90.0
# Upper Limit : 170.0
# Outliers : 1435
#           id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 59        74  20431.0       1   164.0    64.0  180.0   90.0            1
# 61        79  20960.0       2   165.0    75.0  180.0   90.0            3
# 101      136  18718.0       1   167.0    80.0  190.0   90.0            2
# 209      288  18169.0       2   172.0    62.0   80.0   70.0            1
# 230      318  23376.0       2   175.0    75.0  180.0  100.0            3
# ...      ...      ...     ...     ...     ...    ...    ...          ...
# 69587  99398  23223.0       1   169.0   101.0  180.0  110.0            1
# 69593  99405  16781.0       2   179.0    93.0  180.0  100.0            1
# 69830  99734  22552.0       2   163.0    67.0  180.0  100.0            2
# 69894  99835  16857.0       1   160.0    70.0  200.0  100.0            1
# 69997  99996  19066.0       2   183.0   105.0  180.0   90.0            3
#
#        gluc  smoke  alco  active  cardio  age_years
# 59        1      1     0       1       1         56
# 61        1      0     0       1       1         57
# 101       1      0     1       0       0         51
# 209       1      0     0       1       0         50
# 230       1      1     1       1       1         64
# ...     ...    ...   ...     ...     ...        ...
# 69587     1      0     0       0       1         64
# 69593     2      0     1       1       1         46
# 69830     1      0     0       0       1         62
# 69894     2      0     0       1       1         46
# 69997     1      0     1       0       1         52
#
# [1435 rows x 14 columns]

# %%
find_outliers(df, "ap_lo")
# Out:
# Column : ap_lo
# Lower Limit : 65.0
# Upper Limit : 105.0
# Outliers : 4632
#           id      age  gender  height  weight  ap_hi   ap_lo  cholesterol  \
# 4          4  17474.0       1   156.0    56.0  100.0    60.0            1
# 9         14  19834.0       1   164.0    68.0  110.0    60.0            1
# 23        33  23376.0       2   156.0    45.0  110.0    60.0            1
# 43        58  20556.0       2   159.0    63.0  120.0    60.0            1
# 50        65  18238.0       1   160.0    75.0  100.0    60.0            1
# ...      ...      ...     ...     ...     ...    ...     ...          ...
# 69929  99891  19834.0       1   164.0    85.0  165.0   110.0            3
# 69932  99897  15243.0       2   171.0    67.0  110.0    60.0            1
# 69937  99908  14489.0       1   160.0    53.0   90.0    60.0            1
# 69967  99955  21416.0       2   168.0    63.0  140.0  1000.0            1
# 69978  99967  18800.0       1   163.0    78.0   90.0    60.0            1
#
#        gluc  smoke  alco  active  cardio  age_years
# 4         1      0     0       0       0         48
# 9         1      0     0       0       0         54
# 23        1      0     0       1       0         64
# 43        1      0     0       1       1         56
# 50        1      0     0       0       0         50
# ...     ...    ...   ...     ...     ...        ...
# 69929     3      0     0       1       1         54
# 69932     1      0     0       1       0         42
# 69937     1      0     0       1       0         40
# 69967     1      0     0       1       1         59
# 69978     1      0     0       1       1         51
#
# [4632 rows x 14 columns]

# %% [markdown]
# > Z-SCORE

# %%
# Z-score FOR WEIGHT

import numpy as np
from scipy import stats

z_score = np.abs(stats.zscore(df["weight"]))

outliers = df[z_score > 3]

print("Weight Outliers using Z-score :", len(outliers))
# Out:
# Weight Outliers using Z-score : 702

# %%
# Z-score FOR SYSTOLIC BP

z_score = np.abs(stats.zscore(df["ap_hi"]))

outliers = df[z_score > 3]

print("Systolic BP Outliers :", len(outliers))
# Out:
# Systolic BP Outliers : 38

# %%
# Z-score FOR DIASTOLIC BP

z_score = np.abs(stats.zscore(df["ap_lo"]))

outliers = df[z_score > 3]

print("Diastolic BP Outliers :", len(outliers))
# Out:
# Diastolic BP Outliers : 951

# %% [markdown]
# > BOX PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for column in numerical_features:

    plt.figure(figsize=(8, 5))

    sns.boxplot(
        y=df_clean[column]
    )

    plt.title(f"Box Plot of {column}")
    plt.ylabel(column)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# > Clearly Invalid Values Check

# %%
# CHECK INVALID VALUES

print("Invalid Age :", (df["age"] <= 0).sum())

print("Invalid Height :", (df["height"] <= 0).sum())

print("Invalid Weight :", (df["weight"] <= 0).sum())

print("Invalid Systolic BP :", (df["ap_hi"] <= 0).sum())

print("Invalid Diastolic BP :", (df["ap_lo"] <= 0).sum())
# Out:
# Invalid Age : 0
# Invalid Height : 0
# Invalid Weight : 0
# Invalid Systolic BP : 7
# Invalid Diastolic BP : 22

# %% [markdown]
# > Remove Clearly Invalid Values

# %%
# REMOVE CLEARLY INVALID VALUES

df = df[df["height"] > 0]
df = df[df["weight"] > 0]
df = df[df["ap_hi"] > 0]
df = df[df["ap_lo"] > 0]

print("Dataset Shape :", df.shape)
# Out:
# Dataset Shape : (68742, 14)

# %%
# Diastolic BP should be lower than Systolic BP

df = df[df["ap_lo"] < df["ap_hi"]]

print("Dataset Shape After BP Cleaning :", df.shape)
# Out:
# Dataset Shape After BP Cleaning : (68742, 14)

# %% [markdown]
# > Final Check

# %%
# FINAL CHECK

print("Final Dataset Shape :", df.shape)

print("\nMinimum Values:")
print(df[["age", "height", "weight", "ap_hi", "ap_lo"]].min())

print("\nMaximum Values:")
print(df[["age", "height", "weight", "ap_hi", "ap_lo"]].max())
# Out:
# Final Dataset Shape : (68742, 14)
#
# Minimum Values:
# age       10798.0
# height       55.0
# weight       11.0
# ap_hi        16.0
# ap_lo         1.0
# dtype: float64
#
# Maximum Values:
# age       23713.0
# height      250.0
# weight      200.0
# ap_hi     16020.0
# ap_lo       182.0
# dtype: float64

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# > CONVERT AGE IN YEARS

# %%
# Convert age from days to years

df["age_years"] = (df["age"] / 365.25).round().astype(int)

print(df[["age", "age_years"]].head())
# Out:
#        age  age_years
# 0  18393.0         50
# 1  20228.0         55
# 2  18857.0         52
# 3  17623.0         48
# 4  17474.0         48

# %% [markdown]
# > CHECK AGE RANGE

# %%
print("Minimum Age :", df["age_years"].min())
print("Maximum Age :", df["age_years"].max())
# Out:
# Minimum Age : 30
# Maximum Age : 65

# %% [markdown]
# > HEIGHT IN METER

# %%
# Convert height from cm to meter

df["height_m"] = df["height"] / 100

print(df[["height", "height_m"]].head())
# Out:
#    height  height_m
# 0   168.0      1.68
# 1   156.0      1.56
# 2   165.0      1.65
# 3   169.0      1.69
# 4   156.0      1.56

# %% [markdown]
# > CALCULATE BMI

# %%
# Calculate BMI
# Using Formula: BMI = Weight / Height²

df["bmi"] = df["weight"] / (df["height_m"] ** 2)

print(df[["weight", "height_m", "bmi"]].head())
# Out:
#    weight  height_m        bmi
# 0    62.0      1.68  21.967120
# 1    85.0      1.56  34.927679
# 2    64.0      1.65  23.507805
# 3    82.0      1.69  28.710479
# 4    56.0      1.56  23.011177

# %% [markdown]
# > CHECK BMI RANGE

# %%
print("Minimum BMI :", df["bmi"].min())
print("Maximum BMI :", df["bmi"].max())
# Out:
# Minimum BMI : 3.471783865673526
# Maximum BMI : 298.6666666666667

# %% [markdown]
# >BMI CATEGORY

# %%
def bmi_category(bmi):

    if bmi < 18.5:
        return "Underweight"

    elif bmi < 25:
        return "Normal"

    elif bmi < 30:
        return "Overweight"

    else:
        return "Obese"

# %%
# APPLY FUNCTION
df["bmi_category"] = df["bmi"].apply(bmi_category)

# %%
# CHECK
print(df["bmi_category"].value_counts())
# Out:
# bmi_category
# Normal         25456
# Overweight     24649
# Obese          17994
# Underweight      643
# Name: count, dtype: int64

# %% [markdown]
# > PULSE PRESSURE

# %%
# Pulse Pressure

df["pulse_pressure"] = df["ap_hi"] - df["ap_lo"]

print(
    df[
        ["ap_hi", "ap_lo", "pulse_pressure"]
    ].head()
)
# Out:
#    ap_hi  ap_lo  pulse_pressure
# 0  110.0   80.0            30.0
# 1  140.0   90.0            50.0
# 2  130.0   70.0            60.0
# 3  150.0  100.0            50.0
# 4  100.0   60.0            40.0

# %% [markdown]
# > FINAL CHECK

# %%
print(
    df[
        [
            "age_years",
            "height_m",
            "bmi",
            "bmi_category",
            "pulse_pressure"
        ]
    ].head(10)
)
# Out:
#    age_years  height_m        bmi bmi_category  pulse_pressure
# 0         50      1.68  21.967120       Normal            30.0
# 1         55      1.56  34.927679        Obese            50.0
# 2         52      1.65  23.507805       Normal            60.0
# 3         48      1.69  28.710479   Overweight            50.0
# 4         48      1.56  23.011177       Normal            40.0
# 5         60      1.51  29.384676   Overweight            40.0
# 6         61      1.57  37.729725        Obese            50.0
# 7         62      1.78  29.983588   Overweight            40.0
# 8         48      1.58  28.440955   Overweight            40.0
# 9         54      1.64  25.282570   Overweight            50.0

# %%
print("Final Dataset Shape :", df.shape)
# Out:
# Final Dataset Shape : (68742, 18)
